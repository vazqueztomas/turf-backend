# %%
from pypdf import PdfReader
import re

reader = PdfReader("example.pdf")
page = reader.pages[1]
carreras = []


for page in reader.pages:
    if page.page_number == 0:
        continue
    text = page.extract_text()
    lines = text.splitlines()

    ## Extraccion numero de carreras
    for line in lines:
        if "ª Carrera" in line:
            carreras.append({"N de carrera": line})

    # extract_horarios = extraer_horarios(carreras)

print(carreras)
# Out:
# [{'N de carrera': '1ª Carrera 13:30 Hs.'}, {'N de carrera': '2 ª Carrera 14:00 Hs.'}, {'N de carrera': '3 ª Carrera '}, {'N de carrera': '4 ª Carrera '}, {'N de carrera': '5 ª Carrera '}, {'N de carrera': '6 ª Carrera '}, {'N de carrera': '7 ª Carrera '}, {'N de carrera': '8 ª Carrera 17:00 Hs.'}, {'N de carrera': '9 ª Carrera '}, {'N de carrera': '10 ª Carrera '}, {'N de carrera': '12 ª Carrera '}, {'N de carrera': '11 ª Carrera 18:30 Hs.'}, {'N de carrera': '14 ª Carrera '}, {'N de carrera': '13 ª Carrera '}, {'N de carrera': '15 ª Carrera 20:30 Hs.'}]

# %%
import re

# Lista de ejemplo
lines = [
    "LAS 4 M (GCHU) DEBUTA 1 ALELI THUNDER 56 Armoha Leopoldo M 2 Z 3 Dubai Thunder (Gb)-Peaceful Empress Mourazos Carlos A",
    "LOS NOTABLES (AZ) 6S 0P 3S 9S 3S 2 LA SANTIFICADA 56 Moreyra Wilson R Z 3 Le Blues-All Aboard Lusardi Ariel H",
    "LOS TIKIS (AZ) 7L 6L 7L 3P 4L 3 KARINA LETAL 56 Maturan Walter R Z 3 Don Letal-Geishacostera Guerricagoitia Elba",
    "LAS TRES TORDILLAS (AZ) 3P 3P 0P 4 GRAND LUCRE 56 Goncalves Francisco Leandro A 3 Holy Boss (Usa)-Miss Hit Parade Decunto German",
    "KAZAN 7P 6S 6S 5P 6P 5 SUSPIRO DE GLORIA 56 Barrueco Ramiro R Z 3 Security Risk (Usa)-Suspicious Morning (Usa)Guaragna Diego S",
    "CUMENEYEN (LP) 0L 6 SOUTH NAVARRA 56 Balmaceda Lautaro E A 3 Ap Candy-Southern Belle Ibarra Ricardo D",
    "LA KUKENES (VT) 9P 7 FILLYS HALO 56 Velazquez Cristian E Z 3 Sebi Halo-Filly's Tawqueet Tome Victor P",
    "RUBIO B DEBUTA 8 INSTAGRAMADA 56 Medina Jesus A Z 3 Bodemeister (Usa)-Illegally Blonde Etchechoury Juan C (H)",
    "BE Y VI (LP) 9S 9S 6S 9S 7P 9 UNAIZAH (BRZ) 56 Rey Mariano G 4 T 3 Imperatore-Jeddah Buonocore Ricardo",
    "ESTANCIA SANTA MARIA (LP) 4S 5S 6P 0S 8P 1 AIRE LIBRE 56 Barrueco Ramiro R T 3 Hi Happy-Aneta Hildt German R",
    "TEAM CALVENTE (LP) 2P 6P 2 STROGONOFF PASS 56 Calvente Gustavo E Z 3 Distinctiv Passion (Usa)-Tartara Key Calvente Hector G",
    "FELIPE (LP) DEBUTA 3 PIZZI 56 Piliero Sergio A Z 3 Angiolo-Cherry Filly Olivera Fabian A",
    "CUMENEYEN (LP) 0P 4 FUEGO CARAMELO 56 Balmaceda Lautaro E ZC 3 Ap Candy-Fortunate Baby Ibarra Ricardo D",
    "EL REY LEON (Rº) 0P 5 WILD WHISHES 56 Enrique Brian R Z 3 Lizard Island (Usa)-Win The Race Van Tuyne Ricardo A",
    "PASCUAL (AZ) 5L 7L 7P 3P 6 TAHYI TAROVA 56 Chavez Lucas I De Jesus 4 Z 3 Strategic Prince (Gb)-Sand Glass Barrionuevo Oscar A",
    "ABUELO CHICHE (AZ) 9P 7 COLISEE ROMAIN 56 Aserito Maximiliano Z 3 Que Vida Buena-Que Mona (Usa) Sarno Gonzalo A",
    "ST. LOS CROCANTES (LP) DEBUTA 8 KLISHCO 56 Coria Facundo M Z 3 Homage (Usa)-Rusa Identica Villa Fabrizio",
]

# Regex para identificar el patrón de las últimas 5 carreras
race_pattern = re.compile(r"(\d+[SPZL]{1}\s*){1,5}$")

# Regex para identificar el número del caballo
horse_number_pattern = re.compile(r"(\d+)(?![^\d\s])")

# Lista para almacenar las carreras separadas
separated_races = []
current_race = []

# Iterar por cada línea en el array de ejemplo
for line in lines:
    # Verificar si la línea cumple con el patrón de las últimas 5 carreras
    if race_pattern.search(line):
        # Buscar el número del caballo al final de la línea
        horse_number_match = horse_number_pattern.search(line)
        if horse_number_match:
            # Si la línea contiene un número de caballo, se considera un nuevo bloque de carrera
            if current_race:
                # Si ya hay una carrera en curso, agregarla a la lista de carreras separadas
                separated_races.append(current_race)
                current_race = []  # Resetear la carrera en curso
            current_race.append(line)  # Agregar la línea a la carrera en curso
        else:
            # Si no hay un número de caballo, simplemente agregarla a la carrera actual
            current_race.append(line)

# Agregar la última carrera si existe
if current_race:
    separated_races.append(current_race)

# Mostrar las carreras separadas
for i, race in enumerate(separated_races, 1):
    print(f"Carrera {i}:")
    for line in race:
        print(line)
    print("\n")

# %%
import re

# Lista de ejemplo
lines = [
    "LAS 4 M (GCHU) DEBUTA 1 ALELI THUNDER 56 Armoha Leopoldo M 2 Z 3 Dubai Thunder (Gb)-Peaceful Empress Mourazos Carlos A",
    "LOS NOTABLES (AZ) 6S 0P 3S 9S 3S 2 LA SANTIFICADA 56 Moreyra Wilson R Z 3 Le Blues-All Aboard Lusardi Ariel H",
    "LOS TIKIS (AZ) 7L 6L 7L 3P 4L 3 KARINA LETAL 56 Maturan Walter R Z 3 Don Letal-Geishacostera Guerricagoitia Elba",
    "LAS TRES TORDILLAS (AZ) 3P 3P 0P 4 GRAND LUCRE 56 Goncalves Francisco Leandro A 3 Holy Boss (Usa)-Miss Hit Parade Decunto German",
    "KAZAN 7P 6S 6S 5P 6P 5 SUSPIRO DE GLORIA 56 Barrueco Ramiro R Z 3 Security Risk (Usa)-Suspicious Morning (Usa)Guaragna Diego S",
    "CUMENEYEN (LP) 0L 6 SOUTH NAVARRA 56 Balmaceda Lautaro E A 3 Ap Candy-Southern Belle Ibarra Ricardo D",
    "LA KUKENES (VT) 9P 7 FILLYS HALO 56 Velazquez Cristian E Z 3 Sebi Halo-Filly's Tawqueet Tome Victor P",
    "RUBIO B DEBUTA 8 INSTAGRAMADA 56 Medina Jesus A Z 3 Bodemeister (Usa)-Illegally Blonde Etchechoury Juan C (H)",
    "BE Y VI (LP) 9S 9S 6S 9S 7P 9 UNAIZAH (BRZ) 56 Rey Mariano G 4 T 3 Imperatore-Jeddah Buonocore Ricardo",
    "ESTANCIA SANTA MARIA (LP) 4S 5S 6P 0S 8P 1 AIRE LIBRE 56 Barrueco Ramiro R T 3 Hi Happy-Aneta Hildt German R",
    "TEAM CALVENTE (LP) 2P 6P 2 STROGONOFF PASS 56 Calvente Gustavo E Z 3 Distinctiv Passion (Usa)-Tartara Key Calvente Hector G",
    "FELIPE (LP) DEBUTA 3 PIZZI 56 Piliero Sergio A Z 3 Angiolo-Cherry Filly Olivera Fabian A",
    "CUMENEYEN (LP) 0P 4 FUEGO CARAMELO 56 Balmaceda Lautaro E ZC 3 Ap Candy-Fortunate Baby Ibarra Ricardo D",
    "EL REY LEON (Rº) 0P 5 WILD WHISHES 56 Enrique Brian R Z 3 Lizard Island (Usa)-Win The Race Van Tuyne Ricardo A",
    "PASCUAL (AZ) 5L 7L 7P 3P 6 TAHYI TAROVA 56 Chavez Lucas I De Jesus 4 Z 3 Strategic Prince (Gb)-Sand Glass Barrionuevo Oscar A",
    "ABUELO CHICHE (AZ) 9P 7 COLISEE ROMAIN 56 Aserito Maximiliano Z 3 Que Vida Buena-Que Mona (Usa) Sarno Gonzalo A",
    "ST. LOS CROCANTES (LP) DEBUTA 8 KLISHCO 56 Coria Facundo M Z 3 Homage (Usa)-Rusa Identica Villa Fabrizio",
]

# Regex para las últimas 5 carreras
race_pattern = re.compile(
    r"""
    (?:DEBUTA|                  # "DEBUTA"
    (\d+[SPZL]\s*){1,5})        # Hasta 5 resultados como "6S", "0P", etc.
    """,
    re.VERBOSE,
)

# Regex para el número del caballo (el que marca el cambio de carrera)
horse_number_pattern = re.compile(r"\d+$")

# Variable para almacenar las carreras separadas
separated_races = []
current_race = []

# Iteramos por cada línea
for line in lines:
    # Si la línea cumple con el patrón de las últimas 5 carreras
    if race_pattern.search(line):
        # Verificamos si la línea tiene el número del caballo al final
        horse_number_match = horse_number_pattern.search(line)
        if horse_number_match:
            # Si ya tenemos una carrera en curso, la guardamos
            if current_race:
                separated_races.append(current_race)
                current_race = []
            # Agregamos la línea actual a la carrera en curso
            current_race.append(line)
        else:
            # Si no tiene número de caballo al final, simplemente agregamos la línea a la carrera actual
            current_race.append(line)

# Agregamos la última carrera (si existe)
if current_race:
    separated_races.append(current_race)

# Mostrar las carreras separadas
for race in separated_races:
    print("Carrera:")
    for line in race:
        print(line)
    print("\n")
# Out:
# Carrera:
# LAS 4 M (GCHU) DEBUTA 1 ALELI THUNDER 56 Armoha Leopoldo M 2 Z 3 Dubai Thunder (Gb)-Peaceful Empress Mourazos Carlos A
# LOS NOTABLES (AZ) 6S 0P 3S 9S 3S 2 LA SANTIFICADA 56 Moreyra Wilson R Z 3 Le Blues-All Aboard Lusardi Ariel H
# LOS TIKIS (AZ) 7L 6L 7L 3P 4L 3 KARINA LETAL 56 Maturan Walter R Z 3 Don Letal-Geishacostera Guerricagoitia Elba
# LAS TRES TORDILLAS (AZ) 3P 3P 0P 4 GRAND LUCRE 56 Goncalves Francisco Leandro A 3 Holy Boss (Usa)-Miss Hit Parade Decunto German
# KAZAN 7P 6S 6S 5P 6P 5 SUSPIRO DE GLORIA 56 Barrueco Ramiro R Z 3 Security Risk (Usa)-Suspicious Morning (Usa)Guaragna Diego S
# CUMENEYEN (LP) 0L 6 SOUTH NAVARRA 56 Balmaceda Lautaro E A 3 Ap Candy-Southern Belle Ibarra Ricardo D
# LA KUKENES (VT) 9P 7 FILLYS HALO 56 Velazquez Cristian E Z 3 Sebi Halo-Filly's Tawqueet Tome Victor P
# RUBIO B DEBUTA 8 INSTAGRAMADA 56 Medina Jesus A Z 3 Bodemeister (Usa)-Illegally Blonde Etchechoury Juan C (H)
# ...

# %%
car = []


def extraer_horarios():
    for page in reader.pages:
        if page.page_number == 0:
            continue
        text = page.extract_text()
        lines = text.splitlines()

    for line in lines:
        if "ª Carrera" in line:
            horarios.append({"N de carrera": line})


carreras
# Out:
# [{'N de carrera': '1ª Carrera 13:30 Hs.'},
#  {'N de carrera': '2 ª Carrera 14:00 Hs.'},
#  {'N de carrera': '3 ª Carrera '},
#  {'N de carrera': '4 ª Carrera '},
#  {'N de carrera': '5 ª Carrera '},
#  {'N de carrera': '6 ª Carrera '},
#  {'N de carrera': '7 ª Carrera '},
#  {'N de carrera': '8 ª Carrera 17:00 Hs.'},
#  {'N de carrera': '9 ª Carrera '},
#  {'N de carrera': '10 ª Carrera '},
#  {'N de carrera': '12 ª Carrera '},
#  {'N de carrera': '11 ª Carrera 18:30 Hs.'},
#  {'N de carrera': '14 ª Carrera '},
#  {'N de carrera': '13 ª Carrera '},
#  {'N de carrera': '15 ª Carrera 20:30 Hs.'}]

# %%
import pytest
import psycopg2
from psycopg2 import OperationalError
from database.database import get_connection
import os


def test_all_queries() -> None:
    
    try:
        connection = get_connection()
        print("Connection successful", connection)
    except OperationalError as e:
        print(f"Connection failed: {e}")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.local/share/virtualenvs/turf-backend-qbzBVfxu/lib/python3.12/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/.local/share/virtualenvs/turf-backend-qbzBVfxu/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# ...
